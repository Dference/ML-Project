# %%
import os
import csv
import numpy as np
import pandas as pd
import sklearn as skl
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, OneHotEncoder
import tensorflow as tf
import keras_tuner as kt

# %%
nfl_data = pd.read_csv(r'C:\Users\wmk71\UNC-VIRT-DATA-PT-03-2024-U-LOLC\Project_4\archive\nfl_team_stats_2002-2023.csv')

# %%
nfl_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5929 entries, 0 to 5928
# Data columns (total 53 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   season                 5929 non-null   int64
#  1   week                   5929 non-null   object
#  2   date                   5929 non-null   object
#  3   away                   5929 non-null   object
#  4   home                   5929 non-null   object
#  5   score_away             5929 non-null   int64
#  6   score_home             5929 non-null   int64
#  7   first_downs_away       5929 non-null   int64
#  8   first_downs_home       5929 non-null   int64
#  9   third_down_comp_away   5929 non-null   int64
#  10  third_down_att_away    5929 non-null   int64
#  11  third_down_comp_home   5929 non-null   int64
#  12  third_down_att_home    5929 non-null   int64
#  13  fourth_down_comp_away  5929 non-null   int64
#  14  fourth_down_att_away   5929 non-null   int64
#  15  fourth_down_comp_home  5929 non-null   int64
#  16  fourth_down_att_home   5929 non-null   int64
#  17  plays_away             5929 non-null   int64
#  18  plays_home             5929 non-null   int64
#  19  drives_away            5929 non-null   int64
#  20  drives_home            5929 non-null   int64
#  21  yards_away             5929 non-null   int64
#  22  yards_home             5929 non-null   int64
#  23  pass_comp_away         5929 non-null   int64
#  24  pass_att_away          5929 non-null   int64
#  25  pass_yards_away        5929 non-null   int64
#  26  pass_comp_home         5929 non-null   int64
#  27  pass_att_home          5929 non-null   int64
#  28  pass_yards_home        5929 non-null   int64
#  29  sacks_num_away         5929 non-null   int64
#  30  sacks_yards_away       5929 non-null   int64
#  31  sacks_num_home         5929 non-null   int64
#  32  sacks_yards_home       5929 non-null   int64
#  33  rush_att_away          5929 non-null   int64
#  34  rush_yards_away        5929 non-null   int64
#  35  rush_att_home          5929 non-null   int64
#  36  rush_yards_home        5929 non-null   int64
#  37  pen_num_away           5929 non-null   int64
#  38  pen_yards_away         5929 non-null   int64
#  39  pen_num_home           5929 non-null   int64
#  40  pen_yards_home         5929 non-null   int64
#  41  redzone_comp_away      5929 non-null   int64
#  42  redzone_att_away       5929 non-null   int64
#  43  redzone_comp_home      5929 non-null   int64
#  44  redzone_att_home       5929 non-null   int64
#  45  fumbles_away           5929 non-null   int64
#  46  fumbles_home           5929 non-null   int64
#  47  interceptions_away     5929 non-null   int64
#  48  interceptions_home     5929 non-null   int64
#  49  def_st_td_away         5929 non-null   int64
#  50  def_st_td_home         5929 non-null   int64
#  51  possession_away        5929 non-null   object
#  52  possession_home        5929 non-null   object
# dtypes: int64(47), object(6)
# memory usage: 2.4+ MB

# %%
nfl_data.head()
# Out:
#    season week        date      away     home  score_away  score_home  \
# 0    2002    1  2002-09-05     49ers   Giants          16          13
# 1    2002    1  2002-09-08      Jets    Bills          37          31
# 2    2002    1  2002-09-08   Vikings    Bears          23          27
# 3    2002    1  2002-09-08  Chargers  Bengals          34           6
# 4    2002    1  2002-09-08    Chiefs   Browns          40          39
#
#    first_downs_away  first_downs_home  third_down_comp_away  ...  \
# 0                13                21                     4  ...
# 1                18                26                     2  ...
# 2                19                20                     5  ...
# 3                27                13                     6  ...
# 4                24                24                     5  ...
#
#    redzone_comp_home  redzone_att_home  fumbles_away  fumbles_home  \
# 0                  0                 6             0             0
# 1                  0                 8             1             1
# 2                  0                 6             1             1
# 3                  0                 5             0             0
# 4                  0                10             0             1
#
#    interceptions_away  interceptions_home  def_st_td_away  def_st_td_home  \
# 0                   1                   3               0               0
# 1                   0                   2               2               0
# 2                   2                   1               0               0
# 3                   0                   1               0               0
# 4                   1                   0               0               0
#
#    possession_away  possession_home
# 0            27:32            32:28
# 1            21:06            39:08
# 2            31:31            28:29
# 3            37:48            22:12
# 4            30:16            29:44
#
# [5 rows x 53 columns]

# %%
# Add a new column for the result
nfl_data['result'] = ''

# Iterate through the rows to determine the outcome
for index, row in nfl_data.iterrows():
    if row['score_away'] > row['score_home']:
        nfl_data.at[index, 'result'] = 0 # Away Win
    elif row['score_away'] < row['score_home']:
        nfl_data.at[index, 'result'] = 1 # Away Loss
    else:
        nfl_data.at[index, 'result'] = 2 # Tie

# Print out the updated DataFrame with results
print(nfl_data[['score_away', 'score_home', 'result']].head())
# Out:
#    score_away  score_home result
# 0          16          13      0
# 1          37          31      0
# 2          23          27      1
# 3          34           6      0
# 4          40          39      0

# %%
team_name_to_id = {
    'Cardinals': 1,
    'Falcons': 2,
    'Ravens': 3,
    'Bills': 4,
    'Panthers': 5,
    'Bears': 6,
    'Bengals': 7,
    'Browns': 8,
    'Cowboys': 9,
    'Broncos': 10,
    'Lions': 11,
    'Packers': 12,
    'Texans': 13,
    'Colts': 14,
    'Jaguars': 15,
    'Chiefs': 16,
    'Raiders': 17,
    'Chargers': 18,
    'Rams': 19,
    'Dolphins': 20,
    'Vikings': 21,
    'Patriots': 22,
    'Saints': 23,
    'Giants': 24,
    'Jets': 25,
    'Eagles': 26,
    'Steelers': 27,
    '49ers': 28,
    'Seahawks': 29,
    'Buccaneers': 30,
    'Titans': 31,
    'Commanders': 32,
    # Add all other team names and their corresponding IDs
}
# Replace team names with numeric IDs using a for loop
for index, row in nfl_data.iterrows():
    home_team = row['home']
    away_team = row['away']
    
    if home_team in team_name_to_id:
        nfl_data.at[index, 'home'] = team_name_to_id[home_team]
    
    if away_team in team_name_to_id:
        nfl_data.at[index, 'away'] = team_name_to_id[away_team]

# Display the DataFrame with team names replaced by IDs
print(nfl_data.head)
# Out:
# <bound method NDFrame.head of       season        week        date away home  score_away  score_home  \
# 0       2002           1  2002-09-05   28   24          16          13
# 1       2002           1  2002-09-08   25    4          37          31
# 2       2002           1  2002-09-08   21    6          23          27
# 3       2002           1  2002-09-08   18    7          34           6
# 4       2002           1  2002-09-08   16    8          40          39
# ...      ...         ...         ...  ...  ...         ...         ...
# 5924    2023    Division  2024-01-21   30   11          23          31
# 5925    2023    Division  2024-01-21   16    4          27          24
# 5926    2023  Conference  2024-01-28   16    3          17          10
# 5927    2023  Conference  2024-01-28   11   28          31          34
# 5928    2023   Superbowl  2024-02-11   28   16          22          25
#
#       first_downs_away  first_downs_home  third_down_comp_away  ...  \
# 0                   13                21                     4  ...
# 1                   18                26                     2  ...
# 2                   19                20                     5  ...
# 3                   27                13                     6  ...
# 4                   24                24                     5  ...
# ...                ...               ...                   ...  ...
# 5924                23                26                     4  ...
# 5925                21                27                     1  ...
# 5926                22                16                     8  ...
# 5927                28                23                     6  ...
# 5928                23                24                     3  ...
#
#       redzone_att_home  fumbles_away  fumbles_home  interceptions_away  \
# 0                    6             0             0                   1
# 1                    8             1             1                   0
# 2                    6             1             1                   2
# 3                    5             0             0                   0
# 4                   10             0             1                   1
# ...                ...           ...           ...                 ...
# 5924                 4             0             0                   2
# 5925                 4             1             0                   0
# 5926                 1             0             2                   0
# 5927                 5             1             0                   0
# 5928                 6             2             1                   0
#
#       interceptions_home  def_st_td_away  def_st_td_home  possession_away  \
# 0                      3               0               0            27:32
# 1                      2               2               0            21:06
# 2                      1               0               0            31:31
# 3                      1               0               0            37:48
# 4                      0               0               0            30:16
# ...                  ...             ...             ...              ...
# 5924                   0               0               0            28:00
# 5925                   0               0               0            22:57
# 5926                   1               0               0            37:30
# 5927                   1               0               0            27:48
# 5928                   1               0               0            38:31
#
#       possession_home  result
# 0               32:28       0
# 1               39:08       0
# 2               28:29       1
# 3               22:12       0
# 4               29:44       0
# ...               ...     ...
# 5924            32:00       1
# 5925            37:03       0
# 5926            22:30       0
# 5927            32:12       1
# 5928            36:26       1
#
# [5929 rows x 54 columns]>

# %%
# Drop rows with any missing values
nfl_data_clean = nfl_data.drop(columns=['date', 'week', 'possession_away', 'possession_home'])

nfl_data_clean = nfl_data_clean.dropna()

nfl_data_clean
# Out:
#       season away home  score_away  score_home  first_downs_away  \
# 0       2002   28   24          16          13                13
# 1       2002   25    4          37          31                18
# 2       2002   21    6          23          27                19
# 3       2002   18    7          34           6                27
# 4       2002   16    8          40          39                24
# ...      ...  ...  ...         ...         ...               ...
# 5924    2023   30   11          23          31                23
# 5925    2023   16    4          27          24                21
# 5926    2023   16    3          17          10                22
# 5927    2023   11   28          31          34                28
# 5928    2023   28   16          22          25                23
#
#       first_downs_home  third_down_comp_away  third_down_att_away  \
# 0                   21                     4                   12
# 1                   26                     2                    8
# 2                   20                     5                   13
# 3                   13                     6                   10
# 4                   24                     5                   11
# ...                ...                   ...                  ...
# 5924                26                     4                   12
# 5925                27                     1                    5
# 5926                16                     8                   18
# 5927                23                     6                   12
# 5928                24                     3                   12
#
#       third_down_comp_home  ...  redzone_att_away  redzone_comp_home  \
# 0                        9  ...                 8                  0
# 1                        7  ...                 9                  0
# 2                        7  ...                 7                  0
# 3                        4  ...                 7                  0
# 4                        4  ...                10                  0
# ...                    ...  ...               ...                ...
# 5924                     6  ...                 3                  3
# 5925                     7  ...                 4                  3
# 5926                     3  ...                 3                  0
# 5927                     6  ...                 4                  4
# 5928                     9  ...                 2                  2
#
#       redzone_att_home  fumbles_away  fumbles_home  interceptions_away  \
# 0                    6             0             0                   1
# 1                    8             1             1                   0
# 2                    6             1             1                   2
# 3                    5             0             0                   0
# 4                   10             0             1                   1
# ...                ...           ...           ...                 ...
# 5924                 4             0             0                   2
# 5925                 4             1             0                   0
# 5926                 1             0             2                   0
# 5927                 5             1             0                   0
# 5928                 6             2             1                   0
#
#       interceptions_home  def_st_td_away  def_st_td_home  result
# 0                      3               0               0       0
# 1                      2               2               0       0
# 2                      1               0               0       1
# 3                      1               0               0       0
# 4                      0               0               0       0
# ...                  ...             ...             ...     ...
# 5924                   0               0               0       1
# 5925                   0               0               0       0
# 5926                   1               0               0       0
# 5927                   1               0               0       1
# 5928                   1               0               0       1
#
# [5929 rows x 50 columns]

# %%
# Separate features and target variable
X = nfl_data_clean.drop(['result'], axis=1).values  # Replace 'target_column' with your target column name
y = nfl_data_clean['result'].values

X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=78)

scaler = StandardScaler()

# Fit the StandardScaler
X_scaler = scaler.fit(X_train)

# Scale the data
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %%
print(type(X_train))
print(type(y_train))
print(X_train.dtype)
print(y_train.dtype)
# Out:
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# object
# object

# %%
X_train = X_train.astype('float32')
X_test = X_test.astype('float32')
y_train = y_train.astype('float32')  # or int32, depending on your problem
y_test = y_test.astype('float32')

# %%
# Define the model - deep neural net, i.e., the number of input features and hidden nodes for each layer.

number_input_features = X_train.shape[1]
hidden_nodes_layer1 =  9
hidden_nodes_layer2 = 5
hidden_nodes_layer3 = 1
hidden_nodes_layer4 = 3
hidden_nodes_layer5 = 9
hidden_nodes_layer6 = 5

nn = tf.keras.models.Sequential()

# First hidden layer
nn.add(
    tf.keras.layers.Dense(units=hidden_nodes_layer1, input_dim=number_input_features, activation="sigmoid")
)

# Second hidden layer
nn.add(tf.keras.layers.Dense(units=hidden_nodes_layer2, activation="relu"))

# Third hidden layer
nn.add(tf.keras.layers.Dense(units=hidden_nodes_layer3, activation="relu"))

# Fourth hidden layer
nn.add(tf.keras.layers.Dense(units=hidden_nodes_layer4, activation="relu"))

# Fifth hidden layer
nn.add(tf.keras.layers.Dense(units=hidden_nodes_layer5, activation="relu"))

# Sixth hidden layer
nn.add(tf.keras.layers.Dense(units=hidden_nodes_layer6, activation="relu"))

# Output layer
nn.add(tf.keras.layers.Dense(units=1, activation="sigmoid"))


# Check the structure of the model
nn.summary()
# Out:
# c:\Users\wmk71\anaconda3\Lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense (Dense)                   │ (None, 9)              │           450 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 5)              │            50 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 1)              │             6 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 3)              │             6 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_4 (Dense)                 │ (None, 9)              │            36 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_5 (Dense)                 │ (None, 5)              │            50 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_6 (Dense)                 │ (None, 1)              │             6 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 604 (2.36 KB)
#  Trainable params: 604 (2.36 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
# Compile the model
nn.compile(loss='mean_squared_error', optimizer="adam", metrics=["accuracy"])

# %%
nn.fit(X_train, y_train, epochs=50, batch_size=32, validation_split=0.2)
# Out:
# Epoch 1/50
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.5486 - loss: 0.2543 - val_accuracy: 0.5787 - val_loss: 0.2514
# Epoch 2/50
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.5615 - loss: 0.2494 - val_accuracy: 0.5787 - val_loss: 0.2476
# Epoch 3/50
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.6284 - loss: 0.2451 - val_accuracy: 0.6382 - val_loss: 0.2387
# Epoch 4/50
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.6285 - loss: 0.2384 - val_accuracy: 0.6584 - val_loss: 0.2307
# Epoch 5/50
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.6574 - loss: 0.2288 - val_accuracy: 0.6742 - val_loss: 0.2250
# Epoch 6/50
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.6623 - loss: 0.2281 - val_accuracy: 0.6831 - val_loss: 0.2199
# Epoch 7/50
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.6867 - loss: 0.2205 - val_accuracy: 0.6989 - val_loss: 0.2151
# Epoch 8/50
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.6892 - loss: 0.2143 - val_accuracy: 0.6955 - val_loss: 0.2150
# Epoch 9/50
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.6962 - loss: 0.2173 - val_accuracy: 0.7124 - val_loss: 0.2104
# Epoch 10/50
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7004 - loss: 0.2132 - val_accuracy: 0.7135 - val_loss: 0.2049
# Epoch 11/50
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7253 - loss: 0.2016 - val_accuracy: 0.7315 - val_loss: 0.2045
# Epoch 12/50
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7267 - loss: 0.2034 - val_accuracy: 0.7337 - val_loss: 0.1971
# Epoch 13/50
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7486 - loss: 0.1900 - val_accuracy: 0.7258 - val_loss: 0.2014
# Epoch 14/50
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7289 - loss: 0.2009 - val_accuracy: 0.7326 - val_loss: 0.1990
# Epoch 15/50
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7557 - loss: 0.1864 - val_accuracy: 0.7494 - val_loss: 0.1953
# Epoch 16/50
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7741 - loss: 0.1783 - val_accuracy: 0.7494 - val_loss: 0.1825
# Epoch 17/50
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7576 - loss: 0.1835 - val_accuracy: 0.7708 - val_loss: 0.1744
# Epoch 18/50
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7653 - loss: 0.1783 - val_accuracy: 0.7843 - val_loss: 0.1693
# Epoch 19/50
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7659 - loss: 0.1817 - val_accuracy: 0.7910 - val_loss: 0.1623
# Epoch 20/50
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7946 - loss: 0.1632 - val_accuracy: 0.7843 - val_loss: 0.1647
# Epoch 21/50
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7827 - loss: 0.1692 - val_accuracy: 0.7730 - val_loss: 0.1683
# Epoch 22/50
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7881 - loss: 0.1726 - val_accuracy: 0.7978 - val_loss: 0.1614
# Epoch 23/50
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7853 - loss: 0.1700 - val_accuracy: 0.8124 - val_loss: 0.1529
# Epoch 24/50
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8091 - loss: 0.1606 - val_accuracy: 0.8191 - val_loss: 0.1559
# Epoch 25/50
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8091 - loss: 0.1533 - val_accuracy: 0.7629 - val_loss: 0.1890
# Epoch 26/50
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7963 - loss: 0.1646 - val_accuracy: 0.7933 - val_loss: 0.1598
# Epoch 27/50
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7930 - loss: 0.1647 - val_accuracy: 0.8112 - val_loss: 0.1509
# Epoch 28/50
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7946 - loss: 0.1636 - val_accuracy: 0.8067 - val_loss: 0.1561
# Epoch 29/50
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8188 - loss: 0.1474 - val_accuracy: 0.8225 - val_loss: 0.1496
# Epoch 30/50
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8148 - loss: 0.1504 - val_accuracy: 0.8270 - val_loss: 0.1417
# Epoch 31/50
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8147 - loss: 0.1511 - val_accuracy: 0.8281 - val_loss: 0.1393
# Epoch 32/50
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8370 - loss: 0.1354 - val_accuracy: 0.8247 - val_loss: 0.1431
# Epoch 33/50
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8391 - loss: 0.1365 - val_accuracy: 0.8382 - val_loss: 0.1356
# Epoch 34/50
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8416 - loss: 0.1343 - val_accuracy: 0.8461 - val_loss: 0.1313
# Epoch 35/50
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8522 - loss: 0.1251 - val_accuracy: 0.8270 - val_loss: 0.1437
# Epoch 36/50
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8444 - loss: 0.1307 - val_accuracy: 0.8382 - val_loss: 0.1336
# Epoch 37/50
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8338 - loss: 0.1375 - val_accuracy: 0.8562 - val_loss: 0.1242
# Epoch 38/50
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8501 - loss: 0.1269 - val_accuracy: 0.8562 - val_loss: 0.1216
# Epoch 39/50
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8425 - loss: 0.1340 - val_accuracy: 0.8618 - val_loss: 0.1183
# Epoch 40/50
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8646 - loss: 0.1177 - val_accuracy: 0.8674 - val_loss: 0.1141
# Epoch 41/50
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8567 - loss: 0.1220 - val_accuracy: 0.8090 - val_loss: 0.1562
# Epoch 42/50
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8595 - loss: 0.1189 - val_accuracy: 0.8809 - val_loss: 0.1066
# Epoch 43/50
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8683 - loss: 0.1135 - val_accuracy: 0.8742 - val_loss: 0.1087
# Epoch 44/50
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8768 - loss: 0.1095 - val_accuracy: 0.8865 - val_loss: 0.1018
# Epoch 45/50
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8619 - loss: 0.1206 - val_accuracy: 0.8831 - val_loss: 0.1005
# Epoch 46/50
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8828 - loss: 0.1009 - val_accuracy: 0.8910 - val_loss: 0.0948
# Epoch 47/50
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8915 - loss: 0.0965 - val_accuracy: 0.8798 - val_loss: 0.1044
# Epoch 48/50
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8894 - loss: 0.0938 - val_accuracy: 0.8933 - val_loss: 0.0946
# Epoch 49/50
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8960 - loss: 0.0915 - val_accuracy: 0.9045 - val_loss: 0.0832
# Epoch 50/50
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8928 - loss: 0.0980 - val_accuracy: 0.8888 - val_loss: 0.0982

# %%
# Evaluate the model using the test data
model_loss, model_accuracy = nn.evaluate(X_test_scaled,y_test,verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 47/47 - 0s - 2ms/step - accuracy: 0.6784 - loss: 0.2372
# Loss: 0.2372155487537384, Accuracy: 0.6783546805381775

# %%
feature_columns = [
    'season','away', 'home', 'score_away', 'score_home', 'first_downs_away', 'first_downs_home',
    'third_down_comp_away', 'third_down_att_away', 'third_down_comp_home', 'third_down_att_home',
    'fourth_down_comp_away', 'fourth_down_att_away', 'fourth_down_comp_home', 'fourth_down_att_home',
    'plays_away', 'plays_home', 'drives_away', 'drives_home', 'yards_away', 'yards_home',
    'pass_comp_away', 'pass_att_away', 'pass_yards_away', 'pass_comp_home', 'pass_att_home', 'pass_yards_home',
    'sacks_num_away', 'sacks_yards_away', 'sacks_num_home', 'sacks_yards_home',
    'rush_att_away', 'rush_yards_away', 'rush_att_home', 'rush_yards_home',
    'pen_num_away', 'pen_yards_away', 'pen_num_home', 'pen_yards_home',
    'redzone_comp_away', 'redzone_att_away', 'redzone_comp_home', 'redzone_att_home',
    'fumbles_away', 'fumbles_home', 'interceptions_away', 'interceptions_home',
    'def_st_td_away', 'def_st_td_home'
]

# Create new_matchup DataFrame
new_matchup = pd.DataFrame({
    'home': [32],
    'away': [24], 
    # Include other features with placeholder values
    'season': [0],
    'score_away': [0],
    'score_home': [0],
    'first_downs_away': [0],
    'first_downs_home': [0],
    'third_down_comp_away': [0],
    'third_down_att_away': [0],
    'third_down_comp_home': [0],
    'third_down_att_home': [0],
    'fourth_down_comp_away': [0],
    'fourth_down_att_away': [0],
    'fourth_down_comp_home': [0],
    'fourth_down_att_home': [0],
    'plays_away': [0],
    'plays_home': [0],
    'drives_away': [0],
    'drives_home': [0],
    'yards_away': [0],
    'yards_home': [0],
    'pass_comp_away': [0],
    'pass_att_away': [0],
    'pass_yards_away': [0],
    'pass_comp_home': [0],
    'pass_att_home': [0],
    'pass_yards_home': [0],
    'sacks_num_away': [0],
    'sacks_yards_away': [0],
    'sacks_num_home': [0],
    'sacks_yards_home': [0],
    'rush_att_away': [0],
    'rush_yards_away': [0],
    'rush_att_home': [0],
    'rush_yards_home': [0],
    'pen_num_away': [0],
    'pen_yards_away': [0],
    'pen_num_home': [0],
    'pen_yards_home': [0],
    'redzone_comp_away': [0],
    'redzone_att_away': [0],
    'redzone_comp_home': [0],
    'redzone_att_home': [0],
    'fumbles_away': [0],
    'fumbles_home': [0],
    'interceptions_away': [0],
    'interceptions_home': [0],
    'def_st_td_away': [0],
    'def_st_td_home': [0]
})

new_matchup = new_matchup.reindex(columns=feature_columns, fill_value=0)

print(new_matchup.shape)

new_matchup_scaled = scaler.transform(new_matchup)

predictions = nn.predict(new_matchup_scaled)

predicted_classes = (predictions > 0.5).astype(int)

def display_results(predictions, class_labels):
    probability = predictions[0][0]
    predicted_class = class_labels[0][0]
    
    print(f"Predicted probability of home team winning: {probability:.4f}")
    print(f"Predicted class: {'Home team wins' if predicted_class == 1 else 'Away team wins'}")

display_results(predictions, predicted_classes)
# Out:
# (1, 49)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Predicted probability of home team winning: 0.1520
# Predicted class: Away team wins
# c:\Users\wmk71\anaconda3\Lib\site-packages\sklearn\base.py:432: UserWarning: X has feature names, but StandardScaler was fitted without feature names
#   warnings.warn(
